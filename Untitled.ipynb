# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests 
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import re
import time as t
import random
from itertools import compress 
from itertools import chain

from sportsbooks import cleanMoneylineData
from sportsbooks import getJuice
from sportsbooks import getCasinoProfit
from sportsbooks import getImpliedOdds
from sportsbooks import is_number
from sportsbooks import getCutoffMoneyLine
from sportsbooks import getKellyBet



#draftkings
draftkings_url = 'https://sportsbook.draftkings.com/leagues/mma/2162?category=fight-lines&subcategory=moneyline'
draftkings_soup_object = BeautifulSoup(requests.get(draftkings_url).text)
draftkings_names_html = draftkings_soup_object.select(".sportsbook-outcome-cell__label")
draftkings_odds_html = draftkings_soup_object.select(".sportsbook-outcome-cell__element")
draftkings_names = [x.text for x in draftkings_names_html]
draftkings_odds = [int(x.text) for x in draftkings_odds_html if x.text != '']

draftkings_df = cleanMoneylineData(draftkings_names, draftkings_odds, "draftkings") 

#bet-mgm
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://sports.co.betmgm.com/en/sports/mma-45/betting/usa-9")
t.sleep(random.randint(10, 20))
betmgm_odds_html = driver.find_elements_by_css_selector('.option-indicator')
betmgm_names_html = driver.find_elements_by_css_selector('.participants-pair-game')
length_of_bet_mgm_odds = len([x.text for x in betmgm_odds_html])
betmgm_odds = [x.text for x in betmgm_odds_html if x != ''][(length_of_bet_mgm_odds- (len(betmgm_names_html) * 2)):]

try:
    betmgm_names = [x.text.split('\n') for x in betmgm_names_html]
    betmgm_names = list(chain(*[[x[0], x[1]] for x in betmgm_names]))
    betmgm_names = [x[:-3] for x in betmgm_names if x != '']
    betmgm_df = cleanMoneylineData(betmgm_names, betmgm_odds, "betmgm") 
except: 
    try: 
        driver = webdriver.Chrome(ChromeDriverManager().install())
        driver.get("https://sports.co.betmgm.com/en/sports/mma-45/betting/usa-9")
        t.sleep(random.randint(10, 20))
        betmgm_odds_html = driver.find_elements_by_css_selector('.option-indicator')
        betmgm_names_html = driver.find_elements_by_css_selector('.participants-pair-game')
        length_of_bet_mgm_odds = len([x.text for x in betmgm_odds_html])
        betmgm_odds = [x.text for x in betmgm_odds_html if x != ''][(length_of_bet_mgm_odds- (len(betmgm_names_html) * 2)):]
    except: 
        betmgm_df = pd.DataFrame()   

#fanduel
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://sportsbook.fanduel.com/mma?tab=ufc-fights")
fanduel_raw_data = driver.find_elements_by_css_selector('.bh')
fanduel_data = [x.text.split('\n') for x in fanduel_raw_data]
valid_indices = [len(x)==6 for x in fanduel_data]
fanduel_relevant_data = list(compress(fanduel_data, valid_indices))
fanduel_names = list(chain(*[[x[0], x[1]] for x in fanduel_relevant_data]))
fanduel_odds = list(chain(*[[x[2], x[3]] for x in fanduel_relevant_data]))
fanduel_df = cleanMoneylineData(fanduel_names, fanduel_odds, "fanduel") 

#betonline
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://classic.betonline.ag/sportsbook/martial-arts/mma")
t.sleep(random.randint(10, 20))
betonline_data_html = driver.find_elements_by_css_selector('.bdevtt')
betonline_data = np.array([x.text for x in betonline_data_html])
indices_to_remove = []
for i in range(0, len(betonline_data)):
    if pd.Series(betonline_data[i]).isin(["Un", "Ov"])[0]:
        indices_to_remove.append([i, i+1, i+2, i+3])

betonline_data = np.delete(betonline_data, indices_to_remove)
betonline_odds = [x for x in betonline_data if bool(re.search("^\\+", x)) or bool(re.search("^\\-", x))]
betonline_names = [x for x in betonline_data if re.sub('[\s+]', '', re.sub('-', '', (re.sub('\.', '', re.sub('\'', '', x))))).isalpha()
                  and len(x) > 1 
                  and x != "\no\n"
                  and not bool(re.search("\\:", x))]

betonline_df = cleanMoneylineData(betonline_names, betonline_odds, "betonline") 

#bovada
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.bovada.lv/sports/ufc-mma")
t.sleep(random.randint(30, 40))
bovada_odds_html = driver.find_elements_by_css_selector('.bet-btn')
bovada_names_html = driver.find_elements_by_css_selector('.competitor-name')
bovada_odds = [100 if x.text == 'EVEN' else x.text for x in bovada_odds_html]
bovada_names = [x.text for x in bovada_names_html]


try:
    bovada_df = cleanMoneylineData(bovada_names, bovada_odds, "bovada") 
except: 
    bovada_df = pd.DataFrame()   

#mybookie
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://mybookie.ag/sportsbook/ufc/')
t.sleep(random.randint(10, 20))

mybookie_odds_html = driver.find_elements_by_css_selector(".lines-odds")
mybookie_odds = np.array([x.text for x in mybookie_odds_html])
mybookie_odds = mybookie_odds[[is_number(x) for x in mybookie_odds]]

mybookie_html = driver.find_elements_by_css_selector(".justify-content-around")
mybookie_html_cleaned = np.array([x.text for x in mybookie_html])
mybookie_names = []
i = 0
while i < len(mybookie_html_cleaned): 
    if i == 1 or ((i-1)%4==0): 
        mybookie_names.append(mybookie_html_cleaned[i])
    i += 1
mybookie_names = [x.split('\n') for x in mybookie_names]
mybookie_names = sum(mybookie_names, [])
mybookie_df = cleanMoneylineData(mybookie_names, mybookie_odds, "mybookie")

#caesars
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.williamhill.com/us/nj/bet/ufcmma/events/all")
t.sleep(random.randint(10, 20))
betcaesars_names_html = driver.find_elements_by_css_selector('.eventInfo')
betcaesars_odds_html = driver.find_elements_by_css_selector('.SelectionOption')
betcaesars_odds = [x.text for x in betcaesars_odds_html]
betcaesars_names = [x.text for x in betcaesars_names_html]
caesars_df = cleanMoneylineData(betcaesars_names, betcaesars_odds, "caesars") 

#pointsbet
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://nj.pointsbet.com/sports/mma/UFC")
t.sleep(random.randint(10, 20))
pointsbet_data_html = driver.find_elements_by_css_selector('.faxe22p')
pointsbet_relevant_data = [x.text.split('\n') for x in pointsbet_data_html]

try:
    pointsbet_names = list(chain(*[[x[0], x[2]] for x in pointsbet_relevant_data]))
    pointsbet_odds = list(chain(*[[x[1], x[3]] for x in pointsbet_relevant_data]))
    pointsbet_df = cleanMoneylineData(pointsbet_names, pointsbet_odds, "pointsbet") 

except: 
    pointsbet_df = pd.DataFrame()   



#merging data 
merged_data = pd.concat([draftkings_df, fanduel_df, betonline_df, mybookie_df, betmgm_df, bovada_df, caesars_df, pointsbet_df])

num_unique_sportsbooks = pd.DataFrame(merged_data.groupby(['team1', 'team2']).sportsbook.nunique())

best_team1_ml_df = pd.DataFrame() 
best_team2_ml_df = pd.DataFrame() 


best_team1_ml_df['bestTeam1MoneyLine'] = merged_data.groupby(['team1', 'team2'])['team1MoneyLine'].apply(lambda x: max(x))
best_team2_ml_df['bestTeam2MoneyLine'] = merged_data.groupby(['team1', 'team2'])['team2MoneyLine'].apply(lambda x: max(x))


best_team1_ml_df['bestTeam1ImpliedOdds'] = best_team1_ml_df['bestTeam1MoneyLine'].apply(lambda x: getImpliedOdds(x))
best_team2_ml_df['bestTeam2ImpliedOdds'] = best_team2_ml_df['bestTeam2MoneyLine'].apply(lambda x: getImpliedOdds(x))

consensus_team1_prob = pd.DataFrame() 
consensus_team2_prob = pd.DataFrame() 

consensus_team1_prob['consensusTeam1Probability'] = merged_data.groupby(['team1', 'team2'])['true_probability_team1_wins'].apply(lambda x: np.mean(x))
consensus_team2_prob['consensusTeam2Probability'] = merged_data.groupby(['team1', 'team2'])['true_probability_team2_wins'].apply(lambda x: np.mean(x))

consensus_team1_prob['cutOffMLTeam1'] = [getCutoffMoneyLine(x) for x in consensus_team1_prob['consensusTeam1Probability']]
consensus_team2_prob['cutOffMLTeam2'] = [getCutoffMoneyLine(x) for x in consensus_team2_prob['consensusTeam2Probability']]

consensus_data = pd.merge(consensus_team1_prob, consensus_team2_prob, on=['team1', 'team2'], how='outer')
consensus_data = pd.merge(consensus_data, num_unique_sportsbooks, on=['team1', 'team2'], how='outer')


avg_team1_ml = pd.DataFrame() 
avg_team2_ml = pd.DataFrame() 

avg_team1_ml['average_team1_ml'] = merged_data.groupby(['team1', 'team2'])['team1MoneyLine'].apply(lambda x: np.mean(x))
avg_team2_ml['average_team2_ml'] = merged_data.groupby(['team1', 'team2'])['team2MoneyLine'].apply(lambda x: np.mean(x))

merged_data = pd.merge(merged_data, best_team1_ml_df, on=['team1', 'team2'], how='outer')
merged_data = pd.merge(merged_data, num_unique_sportsbooks, on=['team1', 'team2'], how='outer')
merged_data = pd.merge(merged_data, best_team2_ml_df, on=['team1', 'team2'], how='outer')
merged_data = pd.merge(merged_data, consensus_team1_prob, on=['team1', 'team2'], how='outer')
merged_data = pd.merge(merged_data, consensus_team2_prob, on=['team1', 'team2'], how='outer')
merged_data = pd.merge(merged_data, avg_team1_ml, on=['team1', 'team2'], how='outer')
merged_data = pd.merge(merged_data, avg_team2_ml, on=['team1', 'team2'], how='outer')

merged_data['bestJuice'] = getJuice(np.array(merged_data['bestTeam1MoneyLine']), np.array(merged_data['bestTeam2MoneyLine']))

merged_data['isBestTeam1MoneyLine'] = merged_data['bestTeam1MoneyLine'] == merged_data['team1MoneyLine']
merged_data['isBestTeam2MoneyLine'] = merged_data['bestTeam2MoneyLine'] == merged_data['team2MoneyLine'] 
merged_data['providesValue'] = [x or y for x,y in zip(merged_data['isBestTeam1MoneyLine'], merged_data['isBestTeam2MoneyLine'])]
merged_data['bestDeviationTeam1'] = [x - y for x,y in zip(merged_data['consensusTeam1Probability'], merged_data['bestTeam1ImpliedOdds'])]
merged_data['bestDeviationTeam2'] = [x - y for x,y in zip(merged_data['consensusTeam2Probability'], merged_data['bestTeam2ImpliedOdds'])]
merged_data['kellyBetTeam2'] = [getKellyBet(x, y, 300) for x,y in zip(merged_data['bestTeam2MoneyLine'], merged_data['consensusTeam2Probability'])]
merged_data['kellyBetTeam1'] = [getKellyBet(x, y, 300) for x,y in zip(merged_data['bestTeam1MoneyLine'], merged_data['consensusTeam1Probability'])]

merged_data = merged_data.reset_index()

for x in range(0, len(merged_data)):
    if merged_data["bestDeviationTeam1"][x] > 0.005 and merged_data["bestDeviationTeam1"][x] > merged_data["bestDeviationTeam2"][x] and merged_data["team1MoneyLine"][x] == merged_data["bestTeam1MoneyLine"][x]: 
        print("Bet " + str(merged_data["kellyBetTeam1"][x]) +  " on " + np.array(merged_data["team1"])[x] + " at " + str(np.array(merged_data["bestTeam1MoneyLine"])[x]) + " at " + np.array(merged_data["sportsbook_x"])[x] + " for deviation of " + str(np.array(merged_data["bestDeviationTeam1"])[x]) + ' while average moneyline is ' +  str(np.array(merged_data["average_team1_ml"])[x]) + ' as determiined by ' + str(merged_data['sportsbook_y'][x]) + ' sportsbooks') 

    if merged_data["bestDeviationTeam2"][x] > 0.005 and merged_data["bestDeviationTeam2"][x] > merged_data["bestDeviationTeam1"][x] and merged_data["team2MoneyLine"][x] == merged_data["bestTeam2MoneyLine"][x]: 
        print("Bet " + str(merged_data["kellyBetTeam2"][x]) +  " on " + np.array(merged_data["team2"])[x] + " at " + str(np.array(merged_data["bestTeam2MoneyLine"])[x]) + " at " + np.array(merged_data["sportsbook_x"])[x] + " for deviation of " + str(np.array(merged_data["bestDeviationTeam2"])[x]) + ' while average moneyline is ' +  str(np.array(merged_data["average_team2_ml"])[x]) + ' as determiined by ' + str(merged_data['sportsbook_y'][x]) + ' sportsbooks') 

        
print("")
print("")
print("")
print("")
print("")
print("")
print("End of betting recommendations.. Here are the best bets for a given fight.")
print("")
print("")
print("")
print("")
print("")
print("")      
        
for x in range(0, len(merged_data)):
    if merged_data["team1MoneyLine"][x] == merged_data["bestTeam1MoneyLine"][x]: 
        print("Bet on " + np.array(merged_data["team1"])[x] + " at " + str(np.array(merged_data["bestTeam1MoneyLine"])[x]) + " at " + np.array(merged_data["sportsbook_x"])[x] + " for deviation of " + str(np.array(merged_data["bestDeviationTeam1"])[x]) + ' while average moneyline is ' +  str(np.array(merged_data["average_team1_ml"])[x]) + ' as determiined by ' + str(merged_data['sportsbook_y'][x]) + ' sportsbooks') 

    if merged_data["team2MoneyLine"][x] == merged_data["bestTeam2MoneyLine"][x]: 
        print("Bet on " + np.array(merged_data["team2"])[x] + " at " + str(np.array(merged_data["bestTeam2MoneyLine"])[x]) + " at " + np.array(merged_data["sportsbook_x"])[x] + " for deviation of " + str(np.array(merged_data["bestDeviationTeam2"])[x]) + ' while average moneyline is ' +  str(np.array(merged_data["average_team2_ml"])[x]) + ' as determiined by ' + str(merged_data['sportsbook_y'][x]) + ' sportsbooks') 


draftkings_index = draftkings_df.index
draftkings_number_of_rows = len(draftkings_index)

fanduel_index = fanduel_df.index
fanduel_number_of_rows = len(fanduel_index)

betonline_index = betonline_df.index
betonline_number_of_rows = len(betonline_index)

mybookie_index = mybookie_df.index
mybookie_number_of_rows = len(mybookie_index)

betmgm_index = betmgm_df.index
betmgm_number_of_rows = len(betmgm_index)

bovada_index = bovada_df.index
bovada_number_of_rows = len(bovada_index)

caesars_index = caesars_df.index
caesars_number_of_rows = len(caesars_index)

pointsbet_index = pointsbet_df.index
pointsbet_number_of_rows = len(pointsbet_index)

print("Draftkings has " + str(draftkings_number_of_rows) + " rows")
print("Fanduel has " + str(fanduel_number_of_rows) + " rows")
print("Betonline has " + str(betonline_number_of_rows) + " rows")
print("Mybookie has " + str(mybookie_number_of_rows) + " rows")
print("Betmgm has " + str(betmgm_number_of_rows) + " rows")
print("Bovada has " + str(bovada_number_of_rows) + " rows")
print("Caesars has " + str(caesars_number_of_rows) + " rows")
print("Pointsbet has " + str(pointsbet_number_of_rows) + " rows")
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/josephfrancia/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/josephfrancia/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/josephfrancia/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/josephfrancia/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/josephfrancia/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/josephfrancia/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 94.0.4606
# [WDM] - Get LATEST driver version for 94.0.4606
# [WDM] - Driver [/Users/josephfrancia/.wdm/drivers/chromedriver/mac64/94.0.4606.61/chromedriver] found in cache
# Bet 4.830240552699861 on PETR YAN at -210 at betonline for deviation of 0.0051938070459138785 while average moneyline is -250.0 as determiined by 4 sportsbooks
# Bet 15.972194685782748 on JON JONES at 150 at draftkings for deviation of 0.03194438937156546 while average moneyline is 123.33333333333333 as determiined by 3 sportsbooks
# Bet 7.1137652062842065 on CARLOS FELIPE at 116 at fanduel for deviation of 0.01273451796186681 while average moneyline is 0.25 as determiined by 4 sportsbooks
# Bet 2.3512363657891058 on ROBERT WHITTAKER at 188 at fanduel for deviation of 0.005116116166300422 while average moneyline is 172.66666666666666 as determiined by 3 sportsbooks
#
#
#
#
#
#
# End of betting recommendations.. Here are the best bets for a given fight.
#
#
#
#
#
#
# Bet on STEPHANIE EGGER at -134 at fanduel for deviation of -0.013671638625646021 while average moneyline is -140.375 as determiined by 8 sportsbooks
# Bet on SHANNA YOUNG at 124 at betonline for deviation of -0.005406505452498045 while average moneyline is 117.125 as determiined by 8 sportsbooks
# Bet on JOHNNY EDUARDO at 210 at fanduel for deviation of -0.0024256056627972034 while average moneyline is 198.75 as determiined by 8 sportsbooks
# Bet on ALEJANDRO PEREZ at -230 at caesars for deviation of -0.017124736468190127 while average moneyline is -246.25 as determiined by 8 sportsbooks
# Bet on DOUGLAS SILVA DE ANDRADE at -260 at fanduel for deviation of -0.026851002624788123 while average moneyline is -267.85714285714283 as determiined by 7 sportsbooks
# Bet on GAETANO PIRRELLO at 220 at betmgm for deviation of -0.007871219597434087 while average moneyline is 213.57142857142858 as determiined by 7 sportsbooks
# Bet on GAETANO PIRRELLO at 220 at caesars for deviation of -0.007871219597434087 while average moneyline is 213.57142857142858 as determiined by 7 sportsbooks
# Bet on DEVONTE SMITH at -150 at draftkings for deviation of -0.02015100601537767 while average moneyline is -152.75 as determiined by 8 sportsbooks
# Bet on DEVONTE SMITH at -150 at betonline for deviation of -0.02015100601537767 while average moneyline is -152.75 as determiined by 8 sportsbooks
# Bet on DEVONTE SMITH at -150 at mybookie for deviation of -0.02015100601537767 while average moneyline is -152.75 as determiined by 8 sportsbooks
# Bet on JAMIE MULLARKEY at 135 at betmgm for deviation of -0.005380908878239277 while average moneyline is 128.5 as determiined by 8 sportsbooks
# Bet on JIRI PROCHAZKA at -120 at mybookie for deviation of -0.029524251492214826 while average moneyline is -120.0 as determiined by 2 sportsbooks
# Bet on DERRICK LEWIS at 275 at betonline for deviation of -0.004678733989626316 while average moneyline is 262.5 as determiined by 2 sportsbooks
# Bet on FRANCIS NGANNOU at -350 at betonline for deviation of -0.03976571045481814 while average moneyline is -350.0 as determiined by 2 sportsbooks
# Bet on FRANCIS NGANNOU at -350 at mybookie for deviation of -0.03976571045481814 while average moneyline is -350.0 as determiined by 2 sportsbooks
# Bet on DUSTIN POIRIER at -400 at betonline for deviation of -0.03809523809523818 while average moneyline is -400.0 as determiined by 2 sportsbooks
# Bet on NATE DIAZ at 300 at betonline for deviation of -0.011904761904761918 while average moneyline is 300.0 as determiined by 2 sportsbooks
# Bet on DUSTIN POIRIER at -400 at mybookie for deviation of -0.03809523809523818 while average moneyline is -400.0 as determiined by 2 sportsbooks
# Bet on NATE DIAZ at 300 at mybookie for deviation of -0.011904761904761918 while average moneyline is 300.0 as determiined by 2 sportsbooks
# Bet on CONOR MCGREGOR at 450 at betonline for deviation of -0.0027734206278842433 while average moneyline is 425.0 as determiined by 2 sportsbooks
# Bet on KAMARU USMAN at -700 at betonline for deviation of -0.05404476119029766 while average moneyline is -700.0 as determiined by 2 sportsbooks
# Bet on KAMARU USMAN at -700 at mybookie for deviation of -0.05404476119029766 while average moneyline is -700.0 as determiined by 2 sportsbooks
# Bet on AMANDA NUNES at -290 at betonline for deviation of -0.024064392996431816 while average moneyline is -290.0 as determiined by 1 sportsbooks
# Bet on KAYLA HARRISON at 245 at betonline for deviation of -0.009380423057079867 while average moneyline is 245.0 as determiined by 1 sportsbooks
# Bet on CRIS CYBORG at -200 at betonline for deviation of -0.023809523809523725 while average moneyline is -200.0 as determiined by 1 sportsbooks
# Bet on KAYLA HARRISON at 170 at betonline for deviation of -0.013227513227513199 while average moneyline is 170.0 as determiined by 1 sportsbooks
# Bet on ISRAEL ADESANYA at -300 at betonline for deviation of -0.025862068965517127 while average moneyline is -300.0 as determiined by 1 sportsbooks
# Bet on JARED CANNONIER at 250 at betonline for deviation of -0.009852216748768461 while average moneyline is 250.0 as determiined by 1 sportsbooks
# Bet on ASPEN LADD at -255 at mybookie for deviation of -0.03527414486921532 while average moneyline is -255.0 as determiined by 1 sportsbooks
# Bet on MACY CHIASSON at 200 at mybookie for deviation of -0.016369047619047616 while average moneyline is 200.0 as determiined by 1 sportsbooks
# Bet on MATHEUS NICOLAU PEREIRA at -170 at mybookie for deviation of -0.027859718125204824 while average moneyline is -170.0 as determiined by 1 sportsbooks
# Bet on TIM ELLIOTT at 140 at mybookie for deviation of -0.018436578171091456 while average moneyline is 140.0 as determiined by 1 sportsbooks
# Bet on CHRIS WADE at 185 at betmgm for deviation of -0.014525317173917973 while average moneyline is 185.0 as determiined by 1 sportsbooks
# Bet on MOVLID KHAYBULAEV at -225 at betmgm for deviation of -0.028659568116230494 while average moneyline is -225.0 as determiined by 1 sportsbooks
# Bet on LOIK RADZHABOV at -200 at betmgm for deviation of -0.023809523809523725 while average moneyline is -200.0 as determiined by 1 sportsbooks
# Bet on RAUSH MANFIO at 170 at betmgm for deviation of -0.013227513227513199 while average moneyline is 170.0 as determiined by 1 sportsbooks
# Bet on MAGOMED MAGOMEDKERIMOV at -225 at betmgm for deviation of -0.03667855323484459 while average moneyline is -225.0 as determiined by 1 sportsbooks
# Bet on RAY COOPER III at 175 at betmgm for deviation of -0.01926550270921129 while average moneyline is 175.0 as determiined by 1 sportsbooks
# Bet on ANTE DELIJA at 185 at betmgm for deviation of -0.014525317173917973 while average moneyline is 185.0 as determiined by 1 sportsbooks
# Bet on BRUNO HENRIQUE CAPPELOZZA at -225 at betmgm for deviation of -0.028659568116230494 while average moneyline is -225.0 as determiined by 1 sportsbooks
# Bet on KAYLA HARRISON at -3000 at betmgm for deviation of -0.04137613975940535 while average moneyline is -3000.0 as determiined by 1 sportsbooks
# Bet on TAYLOR GUARDADO at 1200 at betmgm for deviation of -0.003288872647542476 while average moneyline is 1200.0 as determiined by 1 sportsbooks
# Bet on ANTONIO CARLOS JUNIOR at -275 at betmgm for deviation of -0.03213811420982737 while average moneyline is -275.0 as determiined by 1 sportsbooks
# Bet on MARTHIN HAMLET NIELSEN at 220 at betmgm for deviation of -0.01369521912350602 while average moneyline is 220.0 as determiined by 1 sportsbooks
# Bet on ABIGAIL MONTES at 375 at betmgm for deviation of -0.011292599314377871 while average moneyline is 375.0 as determiined by 1 sportsbooks
# Bet on CLARESSA SHIELDS at -550 at betmgm for deviation of -0.045387562628941835 while average moneyline is -550.0 as determiined by 1 sportsbooks
# Bet on ISLAM MAKHACHEV at -500 at betmgm for deviation of -0.04022988505747127 while average moneyline is -500.0 as determiined by 1 sportsbooks
# Bet on RAFAEL DOS ANJOS at 360 at betmgm for deviation of -0.010494752623688153 while average moneyline is 360.0 as determiined by 1 sportsbooks
# Bet on ROSE NAMAJUNAS at -120 at betmgm for deviation of -0.02371541501976282 while average moneyline is -120.0 as determiined by 1 sportsbooks
# Bet on ZHANG WEILI at 100 at betmgm for deviation of -0.021739130434782594 while average moneyline is 100.0 as determiined by 1 sportsbooks
# Bet on GERMAINE DE RANDAMIE at -175 at betmgm for deviation of -0.02712740190537699 while average moneyline is -175.0 as determiined by 1 sportsbooks
# Bet on IRENE ALDANA at 145 at betmgm for deviation of -0.01739949976438171 while average moneyline is 145.0 as determiined by 1 sportsbooks
# Bet on MATHEUS NICOLAU at -165 at betmgm for deviation of -0.0235492250164131 while average moneyline is -165.0 as determiined by 1 sportsbooks
# Bet on TIM ELLIOT at 140 at betmgm for deviation of -0.015758951084215822 while average moneyline is 140.0 as determiined by 1 sportsbooks
# Bet on MATHEUS NICOLAU PEREIRA at -175 at pointsbet for deviation of -0.03204708960104641 while average moneyline is -175.0 as determiined by 1 sportsbooks
# Bet on TIMOTHY ELLIOTT at 140 at pointsbet for deviation of -0.020983213429256575 while average moneyline is 140.0 as determiined by 1 sportsbooks
# Draftkings has 40 rows
# Fanduel has 56 rows
# Betonline has 97 rows
# Mybookie has 46 rows
# Betmgm has 50 rows
# Bovada has 34 rows
# Caesars has 5 rows
# Pointsbet has 29 rows
